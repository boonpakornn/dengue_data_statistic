# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
#from statsmodels.formula.api import logit, glm
import matplotlib.pyplot as plt

# %%
province1 = 'Bangkok'
province2 = 'bangkok'
level = 'dist'
level_text = 'District Level'

# %%
# data
df_data = pd.read_csv('Data/' + province1 + '/Monthly DF/' + province2 + '_' + level + '_monthly.csv')
df_data = df_data.loc[df_data['year'] == 2017]

num_month = '12'
month = 'Dec'
#ss = 'Season'

# model
#mylogit3 = smf.glm(formula=month + ' ~ bin_pop9s+bowl_pop9s+bucket_pop9s+misc_short_pop9s+jar_pop9s+pottedplant_pop9s+tire_pop9s+misc_tall_pop9s', data=df_data, family=sm.families.Poisson(link=sm.genmod.families.links.log))
mylogit3 = smf.glm(formula=month + ' ~ RF_' + month + '+LST_' + month + '+bin_pop9s+bowl_pop9s+bucket_pop9s+misc_short_pop9s+jar_pop9s+pottedplant_pop9s+tire_pop9s+misc_tall_pop9s', data=df_data, family=sm.families.Poisson(link=sm.genmod.families.links.log))

# output
res3 = mylogit3.fit()
#print('                                    ' + province1 + ' (' + level_text + ')')
#print('                             ' + province1 + ' 2017 (' + level_text + ')')
#print(res3.summary())

# Pass the parameters from each CD to store in a CSV file
coef = res3.params
pval = res3.pvalues

# Normal
#coef.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_coef.csv', encoding = 'utf-8')
#pval.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_pval.csv', encoding = 'utf-8')
#coef.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_coef_2017.csv', encoding = 'utf-8')
#pval.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_pval_2017.csv', encoding = 'utf-8')

# Season/nonseason
#coef.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_coef_' + ss + '.csv', encoding = 'utf-8')
#pval.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_pval_' + ss + '.csv', encoding = 'utf-8')
#coef.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_coef_' + ss + '_2017.csv', encoding = 'utf-8')
#pval.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_pval_' + ss + '_2017.csv', encoding = 'utf-8')

# RF+LST
#coef.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_coef_RF+LST.csv', encoding = 'utf-8')
#pval.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_pval_RF+LST.csv', encoding = 'utf-8')
coef.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_coef_RF+LST_2017.csv', encoding = 'utf-8')
pval.to_csv('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_pval_RF+LST_2017.csv', encoding = 'utf-8')

#plt.rc('figure', figsize=(8, 4.5))
plt.rc('figure', figsize=(8, 5))
plt.text(0.01, 0.01, str(res3.summary()), {'fontsize': 14}, fontproperties = 'monospace') # approach improved by OP -> monospace!
plt.axis('off')
plt.tight_layout()

# Normal
#plt.savefig('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '.png')
#plt.savefig('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_2017.png')

# Season/nonseason
#plt.savefig('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + ss + '.png')
#plt.savefig('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + ss + '_2017.png')

# RF+LST
#plt.savefig('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_RF+LST.png')
plt.savefig('GLM/' + province1 + '/GLM_' + province2 + '_' + level + '_' + num_month + '_' + month + '_RF+LST_2017.png')
