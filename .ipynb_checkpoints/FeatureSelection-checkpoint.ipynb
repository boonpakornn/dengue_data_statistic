# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import os
import matplotlib.pyplot as plt

# %%
# Load the Dengue dataset
#Dengue = datasets.load_Dengue()
df_train =  pd.read_csv('train.csv', header=0, skiprows=0)
df_train = df_train.drop('Unnamed: 0', axis = 1)
df_test =  pd.read_csv('test.csv', header=0, skiprows=0)
df_test = df_test.drop('Unnamed: 0', axis = 1)
index = range(15)
df_result = pd.DataFrame(index = index,columns=['Deleted', 'Rsquared', 'RMSE', 'MAE', 'AIC'])

# %%
columns = df_train.columns.values.tolist()
#name = [100]
#for i in range(15):
#    name.append(columns[4+i])
    
for i in range(15):
    df_result['Deleted'][i] = columns[4+i]
    x_train = df_train.iloc[:,range(4,34)]
    x_train = x_train.drop(x_train.columns[i], axis=1)
    y_train = df_train.iloc[:,[3]]
    x_test = df_test.iloc[:,range(4,34)]
    x_test = x_test.drop(x_test.columns[i], axis=1)
    y_test = df_test.iloc[:,[3]]

    regressor = LinearRegression()
    regressor.fit(x_train, y_train)
    y_pred = regressor.predict(x_test)
    #print('Linear Regression R squared: %.4f' % regressor.score(x_test, y_test))
    df_result['Rsquared'][i] = regressor.score(x_test, y_test)

    # calculate RMSE
    lin_mse = mean_squared_error(y_pred, y_test)
    lin_rmse = np.sqrt(lin_mse)
    #print('Linear Regression RMSE: %.4f' % lin_rmse)
    df_result['RMSE'][i] = lin_mse

    # calculate MAE
    from sklearn.metrics import mean_absolute_error
    lin_mae = mean_absolute_error(y_pred, y_test)
    #print('Linear Regression MAE: %.4f' % lin_mae)
    df_result['MAE'][i] = lin_mae

    # calculate AIC
    resid = y_test - y_pred
    sse = sum(resid.values**2)
    k = 31
    AIC= 2*k - 2*np.log(sse)
    #print('Linear Regression AIC : %.4f' % AIC)
    #print('\n')
    df_result['AIC'][i] = AIC[0]

# %%
df_result
# Out:
#     Deleted    Rsquared      RMSE       MAE      AIC
# 0    DF_wm1 -0.00519465  0.727564  0.500182   44.499
# 1    DF_wm2  0.00953439  0.716903  0.495097  44.5285
# 2    DF_wm3   0.0252103  0.705557  0.493376  44.5604
# 3    RF_wm1   0.0228217  0.707286  0.489304  44.5555
# 4    RF_wm2   0.0229698  0.707179  0.486798  44.5559
# 5    RF_wm3    0.022919  0.707216  0.487051  44.5557
# 6    RF_wm4   0.0230466  0.707123  0.485587   44.556
# 7    RF_wm5   0.0226886  0.707382  0.485396  44.5553
# 8    RF_wm6   0.0228998  0.707229  0.487156  44.5557
# 9   LST_wm1   0.0227191   0.70736  0.485531  44.5553
# 10  LST_wm2   0.0228523  0.707264  0.487096  44.5556
# 11  LST_wm3     0.02292  0.707215  0.486984  44.5557
# 12  LST_wm4   0.0229852  0.707168  0.487322  44.5559
# 13  LST_wm5   0.0228433   0.70727  0.487329  44.5556
# 14  LST_wm6   0.0228105  0.707294  0.488192  44.5555
